# %% [markdown]
# # 9.24
#
#
#
# Scope:
#
# Model higher-order relations with simplicial complexes + accelerate representations with graph hashing for anomaly detection and effect evaluation.
#
# Supervisor Notes:
#
# Explore independently first and confirm genuine interest.
#
# Define the problem and evaluation criteria clearly; ensure reproducibility.
#
# Prospects: large-scale graph scenarios in social networks, IoT security, and biomedicine.
#
# Methods/Baselines (Brief):
#
# Study/replicate: SCHash, SNN/SAN, hashing-accelerated GNNs.
#
# Baselines: GCN family, low-homophily/camouflaged-fraud detectors, dynamic graphs (e.g., AddGraph).
#
# Data (Planned):
#
# Public e-commerce/social/heterogeneous graph datasets with anomaly/fraud labels; construct simplicial complexes (e.g., via clique lifting).
#
# Evaluation (Brief):
#
# Metrics: ROC-AUC, PR-AUC, F1, throughput/latency, memory.
#
# Ablations: with/without simplicial components or hashing, hash length, robustness under low homophily.

# %% [markdown]
# # 10.14
#
# This week, some tasks were formally distributed
#
# 1. In-depth paper reading  Heterogeneous_Graph_Embedding_Made_More_Practical_SIGIR_2025_ and SCHash
# 2. Core concepts of math
# 3. Overall workflow
# 4. Neural network
# 5. Anomaly detection
# 6. Representation
# 7. Simplicial complex
# 8. What is hashing?
# 9. What is anomaly detection?

# %% [markdown]
# # 10.31
# **Tasks for the Next Period:**
#
# 1. **Read the following papers** to understand how simplicial complexes are applied, learn about contrastive learning, grasp its concepts, and understand the concrete steps to implement it:
#    - 1) *"Node Classification in Networks via Simplicial Interactions"*
#    - 2) *"TopoSRL: Topology Preserving Self-Supervised Simplicial Representation Learning"*
#    - 3) *"InfoGCL: Information-Aware Graph Contrastive Learning"*
#
# 2. **Analyze each section of the papers**—understand the dataset characteristics, how the operations are performed on them, what the inputs are, and what the outputs are (node representations/graph representations/edge representations).
#
# 3. **Study the code of SCHash and HGSketch**, align it with the papers section by section, and clarify the implementation details. **HGSketch will be your primary reference paper.**
#
# 4. **After fully understanding the material**, explore whether **contrastive learning can be integrated into HGSketch** to enhance content representations and achieve better detection performance.
#
# ---
# **Key Focus:**
# - Deepen theoretical understanding of simplicial complexes & contrastive learning.
# - Compare datasets & methodologies across papers.
# - Code study with emphasis on HGSketch’s architecture.
# - Innovate by combining HGSketch with contrastive learning techniques.

# %% [markdown]
# # 11.16
#
# ## Honours Project — Risk Assessment Revision (Concise)
#
# 1) Summary of Revisions
#
# Corrected Section 3 table structure and content.
#
# Removed data/ethics items from the RA (to be handled in Ethics paperwork).
#
# Confirmed no additional controls are required at present; Action Register left empty.
#
# 2) Section 3 — Corrected Structure & Entries
#
# Col.3 (Existing Controls): Moved all controls previously listed in col.5 here.
#
# Col.4 (Risk Level after Existing Controls): Now reflects what was in col.6.
#
# Col.5 (Additional Controls): Empty (not required since risk is LOW).
#
# Col.6 (Residual Risk after Additional Controls): Empty (not applicable).
